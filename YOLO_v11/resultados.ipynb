# %% [markdown]
# ## Gráficos

# %% [markdown]
# ![confusionMatrixNormalized.png](attachment:confusionMatrixNormalized.png)
#
# - Taxa de Recall (identificação correta) de 51%. Ou seja, de todos os Waldos existentes, o modelo encontrou 51% e falhou a encontrar 49%.
# - Como só existe a classe Waldo para prever, todas as detecções incorretas em background foram erroneamente classificadas como Waldo.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Verdadeiros positivos: 195. O modelo encontrou com sucesso 195 Waldos.
# - Falsos negativos: 185. O modelo deixou passar 185 Waldos sem serem vistos.
# - Falsos positivos: 156. O modelo "encontrou" um Waldo 156 vezes onde não existia.
# #### Cálculos
# - Cálculo do Recall (Acertos/(Falsos negativos + Acertos)): 195 / 380 = 51.3%
# - Cálculo da Precisão (Acertos/(Acertos + Falsos positivos)): 195 / 351 = 55.6%
